# %%
# stats models, stationary tests, differecing, fit and model forcast
# ARIMA: ADF test, differencing, fit
# ARIMA(p = number of past values, d = number of times the time series is differenced, q = number of past errors)
import pandas as pd
import os
import matplotlib.pyplot as plt

datas = os.path.join("..", "data", "processed")
df = "AAPL.csv"
# Load the first CSV file in the processed data directory
file_path = os.path.join(datas, df)
data = pd.read_csv(file_path)
data.info()

plt.figure(figsize=(26, 6))
data['Volatility'].plot(x = 250, y = 10, linewidth = 0.8)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2515 non-null   int64
#  1   Adj Close   2515 non-null   int64
#  2   Close       2515 non-null   int64
#  3   High        2515 non-null   int64
#  4   Low         2515 non-null   int64
#  5   Open        2515 non-null   int64
#  6   Volume      2515 non-null   int64
#  7   10_MA       2515 non-null   int64
#  8   Volatility  2515 non-null   int64
# dtypes: int64(9)
# memory usage: 177.0 KB

# %%
# keras LSTM, normalise data, create time windows for supervised learning, build and train model, forecast

# %%
# evaluate performance, RMSE, MAE, R2, visualise vs actuals
